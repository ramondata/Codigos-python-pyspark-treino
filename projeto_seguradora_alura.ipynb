# %%
import pandas as pd

# %%
aluguel = pd.read_csv('aluguel.csv', sep=';')

# %%
display(aluguel)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
type(aluguel)
# Out:
# pandas.core.frame.DataFrame

# %%
aluguel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
aluguel.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
aluguel.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
aluguel.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %%
display(aluguel.dtypes)
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %% [markdown]
# Testando o drop duplicate

# %%
tipo_unidade = aluguel['Tipo'].drop_duplicates()

# %%
tipo_unidade
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
tipo_unidade.index = range(0, 22)

# %%
tipo = pd.DataFrame(tipo_unidade)

# %%
tipo.columns.name = 'id'

# %%
tipo
# Out:
# id                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %% [markdown]
# Estrutura dataframe

# %%
#index
index = range(1,11,1)

# %%
#dados
import random
dados = [[1,2,3,4,5,6,7,8,9,0],[100,200,300,400,500,600,700,800,900,1000],
        [1,2,3,4,5,6,7,8,9,0],[100,200,300,400,500,600,700,800,900,1000],
        [1,2,3,4,5,6,7,8,9,0],[100,200,300,400,500,600,700,800,900,1000],
        [1,2,3,4,5,6,7,8,9,0],[100,200,300,400,500,600,700,800,900,1000],
        [1,2,3,4,5,6,7,8,9,0],[100,200,300,400,500,600,700,800,900,1000]]

# %%
dados
# Out:
# [[1, 2, 3, 4, 5, 6, 7, 8, 9, 0],
#  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  [1, 2, 3, 4, 5, 6, 7, 8, 9, 0],
#  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  [1, 2, 3, 4, 5, 6, 7, 8, 9, 0],
#  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  [1, 2, 3, 4, 5, 6, 7, 8, 9, 0],
#  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  [1, 2, 3, 4, 5, 6, 7, 8, 9, 0],
#  [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]]

# %%
df = pd.DataFrame(data=dados, index=index, columns=coluna)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8ffc680bfa8d> in <module>
# ----> 1 df = pd.DataFrame(data=dados, index=index, columns=coluna)
#
# NameError: name 'index' is not defined

# %%
df1 = df+10

# %%
df1
# Out:
#     coluna0  coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  coluna7  \
# 1        11       12       13       14       15       16       17       18
# 2       110      210      310      410      510      610      710      810
# 3        11       12       13       14       15       16       17       18
# 4       110      210      310      410      510      610      710      810
# 5        11       12       13       14       15       16       17       18
# 6       110      210      310      410      510      610      710      810
# 7        11       12       13       14       15       16       17       18
# 8       110      210      310      410      510      610      710      810
# 9        11       12       13       14       15       16       17       18
# 10      110      210      310      410      510      610      710      810
#
#     coluna8  coluna9
# 1        19       10
# 2       910     1010
# 3        19       10
# 4       910     1010
# 5        19       10
# ...

# %%
union = pd.concat([df,df1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2e9da13247f4> in <module>
# ----> 1 union = pd.concat([df,df1])
#
# NameError: name 'df' is not defined

# %%
union
# Out:
#     coluna0  coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  coluna7  \
# 1         1        2        3        4        5        6        7        8
# 2       100      200      300      400      500      600      700      800
# 3         1        2        3        4        5        6        7        8
# 4       100      200      300      400      500      600      700      800
# 5         1        2        3        4        5        6        7        8
# 6       100      200      300      400      500      600      700      800
# 7         1        2        3        4        5        6        7        8
# 8       100      200      300      400      500      600      700      800
# 9         1        2        3        4        5        6        7        8
# 10      100      200      300      400      500      600      700      800
# 1        11       12       13       14       15       16       17       18
# ...

# %%
join = pd.concat([df, df1],axis=1)

# %%
join
# Out:
#     coluna0  coluna1  coluna2  coluna3  coluna4  coluna5  coluna6  coluna7  \
# 1         1        2        3        4        5        6        7        8
# 2       100      200      300      400      500      600      700      800
# 3         1        2        3        4        5        6        7        8
# 4       100      200      300      400      500      600      700      800
# 5         1        2        3        4        5        6        7        8
# 6       100      200      300      400      500      600      700      800
# 7         1        2        3        4        5        6        7        8
# 8       100      200      300      400      500      600      700      800
# 9         1        2        3        4        5        6        7        8
# 10      100      200      300      400      500      600      700      800
#
#     coluna8  coluna9  coluna0  coluna1  coluna2  coluna3  coluna4  coluna5  \
# ...

# %%
list( aluguel['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete',
 'Casa', 'Apartamento',
 'Casa de Condomínio', 'Flat',
]

# %%
residencial
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat']

# %%
filtro_reside = aluguel['Tipo'].isin(residencial)

# %%
aluguel_filtro_reside = aluguel[filtro_reside]

# %%
aluguel_filtro_reside.head(20)
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete               Copacabana        1      0       0    40
# 1                 Casa          Jardim Botânico        2      0       1   100
# 3          Apartamento                   Centro        1      0       0    15
# 4          Apartamento             Higienópolis        1      0       0    48
# 5          Apartamento             Vista Alegre        3      1       0    70
# 6          Apartamento                 Cachambi        2      0       0    50
# 7   Casa de Condomínio          Barra da Tijuca        5      4       5   750
# 8   Casa de Condomínio                    Ramos        2      2       0    65
# 10         Apartamento                   Centro        1      0       0    36
# 11         Apartamento                   Grajaú        2      1       0    70
# 12         Apartamento      Lins de Vasconcelos        3      1       1    90
# ...

# %%
Bairro_filtrar = ['Tijuca']

# %%
Bairro_aluguel = aluguel['Bairro'].isin(Bairro_filtrar)

# %%
Filtra_bairro = aluguel[Bairro_aluguel]

# %%
Filtra_bairro.head(30)
# Out:
#                         Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21               Apartamento  Tijuca        2      1       0   110  1900.0
# 24               Apartamento  Tijuca        2      1       0    78  2000.0
# 28               Apartamento  Tijuca        1      0       0    48   750.0
# 114              Apartamento  Tijuca        2      1       0    80  1800.0
# 118              Apartamento  Tijuca        3      1       0   172  2700.0
# 175  Conjunto Comercial/Sala  Tijuca        0      1       0    20  1000.0
# 190              Apartamento  Tijuca        3      0       0    87  1600.0
# 193  Conjunto Comercial/Sala  Tijuca        0      0       0    21  1000.0
# 207              Box/Garagem  Tijuca        0      0       0     0   380.0
# 218              Apartamento  Tijuca        3      1       1    78  2500.0
# 222  Conjunto Comercial/Sala  Tijuca        0      1       0    32   900.0
# ...

# %%
Filtra_bairro[Filtra_bairro['Area'] > 100]
# Out:
#               Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 21     Apartamento  Tijuca        2      1       0   110  1900.0       700.0
# 118    Apartamento  Tijuca        3      1       0   172  2700.0       780.0
# 269           Casa  Tijuca        4      1       1   191  4000.0       300.0
# 276    Apartamento  Tijuca        3      1       0   129  1800.0       850.0
# 294    Apartamento  Tijuca        3      1       0   164  3500.0      1310.0
# ...            ...     ...      ...    ...     ...   ...     ...         ...
# 32338  Apartamento  Tijuca        3      1       1   165  2650.0      1308.0
# 32449  Apartamento  Tijuca        2      0       1   110  2000.0       450.0
# 32489  Apartamento  Tijuca        3      2       1   122  3000.0      1070.0
# 32587  Apartamento  Tijuca        3      1       0   175  2500.0      1120.0
# 32645  Apartamento  Tijuca        3      2       1   108  2499.0       730.0
#
#         IPTU
# 21     138.0
# 118    170.0
# ...

# %%
morar = ['Tijuca', 'Copacabana', 'Centro']

# %%
filtro_morar = aluguel['Bairro'].isin(morar)

# %%
aluguel[filtro_morar]
#teste de bairro aluguel[filtro_morar]['Bairro'].drop_duplicates()
# Out:
#                           Tipo      Bairro  Quartos  Vagas  Suites  Area  \
# 0                    Quitinete  Copacabana        1      0       0    40
# 3                  Apartamento      Centro        1      0       0    15
# 9      Conjunto Comercial/Sala      Centro        0      3       0   695
# 10                 Apartamento      Centro        1      0       0    36
# 13                 Apartamento  Copacabana        1      0       1    40
# ...                        ...         ...      ...    ...     ...   ...
# 32948  Conjunto Comercial/Sala      Centro        0      0       0    32
# 32950              Apartamento      Tijuca        1      0       0    28
# 32954              Box/Garagem      Centro        0      0       0   755
# 32955                Quitinete      Centro        0      0       0    27
# 32959  Conjunto Comercial/Sala      Centro        0      0       0   250
#
#          Valor  Condominio    IPTU
# 0       1700.0       500.0    60.0
# ...

# %%
tijuca = aluguel['Bairro']=='Tijuca'

# %%
tijuca
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32955    False
# 32956    False
# 32957    False
# 32958    False
# 32959    False
# Name: Bairro, Length: 32960, dtype: bool

# %%
aluguel[tijuca].head(30)
# Out:
#                         Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21               Apartamento  Tijuca        2      1       0   110  1900.0
# 24               Apartamento  Tijuca        2      1       0    78  2000.0
# 28               Apartamento  Tijuca        1      0       0    48   750.0
# 114              Apartamento  Tijuca        2      1       0    80  1800.0
# 118              Apartamento  Tijuca        3      1       0   172  2700.0
# 175  Conjunto Comercial/Sala  Tijuca        0      1       0    20  1000.0
# 190              Apartamento  Tijuca        3      0       0    87  1600.0
# 193  Conjunto Comercial/Sala  Tijuca        0      0       0    21  1000.0
# 207              Box/Garagem  Tijuca        0      0       0     0   380.0
# 218              Apartamento  Tijuca        3      1       1    78  2500.0
# 222  Conjunto Comercial/Sala  Tijuca        0      1       0    32   900.0
# ...

# %%
tij = ['Tijuca']
tijuca_isin = aluguel['Bairro'].isin(tij)

# %%
aluguel[tijuca_isin]
# Out:
#               Tipo  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 21     Apartamento  Tijuca        2      1       0   110  1900.0       700.0
# 24     Apartamento  Tijuca        2      1       0    78  2000.0       700.0
# 28     Apartamento  Tijuca        1      0       0    48   750.0       772.0
# 114    Apartamento  Tijuca        2      1       0    80  1800.0      1100.0
# 118    Apartamento  Tijuca        3      1       0   172  2700.0       780.0
# ...            ...     ...      ...    ...     ...   ...     ...         ...
# 32742  Apartamento  Tijuca        2      1       0    78  1800.0       620.0
# 32800  Apartamento  Tijuca        2      0       0    69  1700.0       760.0
# 32819  Apartamento  Tijuca        2      3       0    70  1680.0       230.0
# 32878  Apartamento  Tijuca        3      1       0    75  1900.0       860.0
# 32950  Apartamento  Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 21     138.0
# 24       NaN
# ...

# %%
#ap = aluguel['Tipo'] == 'Apartamento'
#ap_in = aluguel[ap]
ap1 = ['Apartamento']
ap_isin = aluguel['Tipo'].isin(ap1)

# %%
aluguel[ap_isin]
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
ap = aluguel['Tipo'] == 'Apartamento'
ap_in = aluguel[ap].shape[0]
ap_in
# Out:
# 19532

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False
