# %%
import pandas as pd

# %%
base = pd.read_csv('taxa_evolucao_anual_municipio.csv', sep=',')

# %%
base.head(10)
# Out:
#     ano  id_municipio       municipio regiao_rj  hom_doloso  lesao_corp_morte  \
# 0  2014       3300100  angra dos reis  interior       40.55              0.00
# 1  2015       3300100  angra dos reis  interior       48.86              0.00
# 2  2016       3300100  angra dos reis  interior       44.39              0.52
# 3  2017       3300100  angra dos reis  interior       44.70              0.00
# 4  2018       3300100  angra dos reis  interior       65.87              0.00
# 5  2019       3300100  angra dos reis  interior       43.67              0.00
# 6  2020       3300100  angra dos reis  interior       32.36              0.00
# 7  2014       3300159         aperibe  interior         NaN               NaN
# 8  2015       3300159         aperibe  interior         NaN               NaN
# 9  2016       3300159         aperibe  interior         NaN               NaN
#
#    latrocinio   cvli  hom_por_interv_policial  letalidade_violenta  ...  \
# ...

# %%
base['ano'].drop_duplicates()
# Out:
# 0    2014
# 1    2015
# 2    2016
# 3    2017
# 4    2018
# 5    2019
# 6    2020
# Name: ano, dtype: int64

# %%
base.dtypes
# Out:
# ano                             int64
# id_municipio                    int64
# municipio                      object
# regiao_rj                      object
# hom_doloso                    float64
# lesao_corp_morte              float64
# latrocinio                    float64
# cvli                          float64
# hom_por_interv_policial       float64
# letalidade_violenta           float64
# tentat_hom                    float64
# lesao_corp_dolosa             float64
# estupro                       float64
# hom_culposo                   float64
# lesao_corp_culposa            float64
# roubo_transeunte              float64
# roubo_celular                 float64
# roubo_em_coletivo             float64
# roubo_rua                     float64
# roubo_carga                   float64
# roubo_comercio                float64
# roubo_residencia              float64
# roubo_banco                   float64
# roubo_cx_eletronico           float64
# roubo_conducao_saque          float64
# ...

# %%
new =base['municipio'].drop_duplicates()
r = new.shape[0]

# %%
new.index = range(0,r)

# %%
new.head(40)
# Out:
# 0                  angra dos reis
# 1                         aperibe
# 2                        araruama
# 3                           areal
# 4              armacao dos buzios
# 5                 arraial do cabo
# 6                  barra do pirai
# 7                     barra mansa
# 8                    belford roxo
# 9                      bom jardim
# 10        bom jesus do itabapoana
# 11                      cabo frio
# 12           cachoeiras de macacu
# 13                        cambuci
# 14                      carapebus
# 15      comendador levy gasparian
# 16          campos dos goytacazes
# 17                      cantagalo
# 18                cardoso moreira
# 19                          carmo
# 20              casimiro de abreu
# 21            conceicao de macabu
# 22                       cordeiro
# 23                    duas barras
# 24                duque de caxias
# 25    engenheiro paulo de frontin
# 26                     guapimirim
# ...
